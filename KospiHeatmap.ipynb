# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as st
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_pivot = flights.pivot("month", "year", "passengers")

# %%
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
figsample = plt.figure(figsize=(10,8))
sns.heatmap(flights_pivot)
plt.show()

# %%
figsample.savefig("/Users/user/Desktop/Yonsei/Junior/R & Python Programming/3-2 SelfStudy/sample.jpg")

# %%
kospi23 = pd.read_csv("/Users/user/Desktop/Yonsei/Junior/R & Python Programming/3-2 SelfStudy/Kospi_23.csv")

# %%
kospi23
# Out:
#      Year  Month     Date  ...        Close    Adj Close    Volume
# 0    1997      1   1/1/97  ...   685.840027   685.840027    705400
# 1    1997      2   2/1/97  ...   676.530029   676.530029    634200
# 2    1997      3   3/1/97  ...   677.340027   677.340027    735200
# 3    1997      4   4/1/97  ...   703.229980   703.229980    898700
# 4    1997      5   5/1/97  ...   746.359985   746.359985    963800
# ..    ...    ...      ...  ...          ...          ...       ...
# 308  2022      9   9/1/22  ...  2155.489990  2155.489990   9370100
# 309  2022     10  10/1/22  ...  2293.610107  2293.610107  11769900
# 310  2022     11  11/1/22  ...  2472.530029  2472.530029  12745000
# 311  2022     12  12/1/22  ...  2236.399902  2236.399902   8429100
# 312  2023      1   1/1/23  ...  2395.260010  2395.260010   6771400
#
# [313 rows x 9 columns]

# %%
kospi23 = kospi23.pivot("Year", "Month", "Adj Close")

# %%
kospi23
# Out:
# Month           1            2   ...           11           12
# Year                             ...
# 1997    685.840027   676.530029  ...   407.859985   376.309998
# 1998    567.380005   558.979980  ...   451.880005   562.460022
# 1999    571.429993   520.059998  ...   996.659973  1028.069946
# 2000    943.880005   828.380005  ...   509.230011   504.619995
# 2001    617.909973   578.099976  ...   643.890015   693.700012
# 2002    748.070007   819.989990  ...   724.799988   627.549988
# 2003    591.859985   575.429993  ...   796.179993   810.710022
# 2004    848.500000   883.419983  ...   878.059998   895.919983
# 2005    932.700012  1011.359985  ...  1297.439941  1379.369995
# 2006   1399.829956  1371.589966  ...  1432.209961  1434.459961
# 2007   1360.229980  1417.339966  ...  1906.000000  1897.130005
# 2008   1624.680054  1711.619995  ...  1076.069946  1124.469971
# 2009   1162.109985  1063.030029  ...  1555.599976  1682.770020
# ...

# %%
fig = plt.figure(figsize=(15,12))
sns.heatmap(kospi23, annot=True, fmt='.0f', cmap='jet')
plt.title("Kospi Composite Index Heatmap for 97-22", fontsize=18)
plt.xlabel("Month", fontsize=15)
plt.ylabel('Year', fontsize=15)
plt.show()

# %%
fig.savefig("/Users/user/Desktop/Yonsei/Junior/R & Python Programming/3-2 SelfStudy/KOSPI-Heatmap.pdf")

# %%
fig.savefig("/Users/user/Desktop/Yonsei/Junior/R & Python Programming/3-2 SelfStudy/KOSPI-Heatmap.jpg")

# %%
kospi23_near = pd.read_csv("/Users/user/Desktop/Yonsei/Junior/R & Python Programming/3-2 SelfStudy/Kospi_23.csv")

# %%
kospi23_near
# Out:
#      Year  Month     Date  ...        Close    Adj Close    Volume
# 0    1997      1   1/1/97  ...   685.840027   685.840027    705400
# 1    1997      2   2/1/97  ...   676.530029   676.530029    634200
# 2    1997      3   3/1/97  ...   677.340027   677.340027    735200
# 3    1997      4   4/1/97  ...   703.229980   703.229980    898700
# 4    1997      5   5/1/97  ...   746.359985   746.359985    963800
# ..    ...    ...      ...  ...          ...          ...       ...
# 308  2022      9   9/1/22  ...  2155.489990  2155.489990   9370100
# 309  2022     10  10/1/22  ...  2293.610107  2293.610107  11769900
# 310  2022     11  11/1/22  ...  2472.530029  2472.530029  12745000
# 311  2022     12  12/1/22  ...  2236.399902  2236.399902   8429100
# 312  2023      1   1/1/23  ...  2395.260010  2395.260010   6771400
#
# [313 rows x 9 columns]

# %%
kospi23_near = kospi23_near[['Year', 'Month', 'Adj Close']]

# %%
kospi23_near
# Out:
#      Year  Month    Adj Close
# 0    1997      1   685.840027
# 1    1997      2   676.530029
# 2    1997      3   677.340027
# 3    1997      4   703.229980
# 4    1997      5   746.359985
# ..    ...    ...          ...
# 308  2022      9  2155.489990
# 309  2022     10  2293.610107
# 310  2022     11  2472.530029
# 311  2022     12  2236.399902
# 312  2023      1  2395.260010
#
# [313 rows x 3 columns]

# %%
kospi23_near = kospi23_near[96:]

# %%
kospi23_near
# Out:
#      Year  Month    Adj Close
# 96   2005      1   932.700012
# 97   2005      2  1011.359985
# 98   2005      3   965.679993
# 99   2005      4   911.299988
# 100  2005      5   970.210022
# ..    ...    ...          ...
# 308  2022      9  2155.489990
# 309  2022     10  2293.610107
# 310  2022     11  2472.530029
# 311  2022     12  2236.399902
# 312  2023      1  2395.260010
#
# [217 rows x 3 columns]

# %%
kospi23_near = kospi23_near.pivot("Year", "Month", "Adj Close")

# %%
kospi23_near
# Out:
# Month           1            2   ...           11           12
# Year                             ...
# 2005    932.700012  1011.359985  ...  1297.439941  1379.369995
# 2006   1399.829956  1371.589966  ...  1432.209961  1434.459961
# 2007   1360.229980  1417.339966  ...  1906.000000  1897.130005
# 2008   1624.680054  1711.619995  ...  1076.069946  1124.469971
# 2009   1162.109985  1063.030029  ...  1555.599976  1682.770020
# 2010   1602.430054  1594.579956  ...  1904.630005  2051.000000
# 2011   2069.729980  1939.300049  ...  1847.510010  1825.739990
# 2012   1955.790039  2030.250000  ...  1932.900024  1997.050049
# 2013   1961.939941  2026.489990  ...  2044.869995  2011.339966
# 2014   1941.150024  1979.989990  ...  1980.780029  1915.589966
# 2015   1949.260010  1985.800049  ...  1991.969971  1961.310059
# 2016   1912.060059  1916.660034  ...  1983.479980  2026.459961
# 2017   2067.570068  2091.639893  ...  2476.370117  2467.489990
# ...

# %%
fig2 = plt.figure(figsize=(15,12))
sns.heatmap(kospi23_near, annot=True, fmt='.0f', cmap='jet')
plt.title("Kospi Composite Index Heatmap for 05-22", fontsize=18)
plt.xlabel("Month", fontsize=15)
plt.ylabel('Year', fontsize=15)
plt.show()

# %%
fig2.savefig("/Users/user/Desktop/Yonsei/Junior/R & Python Programming/3-2 SelfStudy/KOSPI-Heatmap_near.pdf")

# %%
fig2.savefig("/Users/user/Desktop/Yonsei/Junior/R & Python Programming/3-2 SelfStudy/KOSPI-Heatmap_near.jpg")

# %%
# ?plt.scatter
# Out:
# Signature:
# plt.scatter(
#     x,
#     y,
#     s=None,
#     c=None,
#     marker=None,
#     cmap=None,
#     norm=None,
#     vmin=None,
#     vmax=None,
#     alpha=None,
#     linewidths=None,
#     *,
#     edgecolors=None,
#     plotnonfinite=False,
#     data=None,
#     **kwargs,
# )
# Docstring:
# A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
# Parameters
# ----------
# x, y : float or array-like, shape (n, )
#     The data positions.
#
# s : float or array-like, shape (n, ), optional
#     The marker size in points**2.
#     Default is ``rcParams['lines.markersize'] ** 2``.
#
# c : array-like or list of colors or color, optional
#     The marker colors. Possible values:
#
#     - A scalar or sequence of n numbers to be mapped to colors using
#       *cmap* and *norm*.
#     - A 2D array in which the rows are RGB or RGBA.
#     - A sequence of colors of length n.
#     - A single color format string.
#
# ...
