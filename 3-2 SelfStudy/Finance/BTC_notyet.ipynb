# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as st
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
bithumb = pd.read_csv("/Users/user/Desktop/Yonsei/Junior/R & Python Programming/3-2 SelfStudy/BTC_KRW Bithumb Historical Data.csv")

# %%
bithumb.head()
# Out:
#   Weekday  Month  Day      Date     Price      Open      High       Low  \
# 0     SAT     12   31  12/31/22  21078000  21092000  21213000  20968000
# 1     FRI     12   30  12/30/22  21092000  21200000  21207000  20748000
# 2    THUR     12   29  12/29/22  21198000  21048000  21289000  20904000
# 3     WED     12   28  12/28/22  21051000  21325000  21372000  21000000
# 4     TUE     12   27  12/27/22  21326000  21683000  21728000  21243000
#
#     Vol. Change %  Volume
# 0  0.58K   -0.07%     580
# 1  0.66K   -0.50%     660
# 2  0.70K    0.70%     700
# 3  0.82K   -1.29%     820
# 4  0.66K   -1.64%     660

# %%
bithumb1 = bithumb[["Month", "Day", "Price"]]

# %%
bithumb1
# Out:
#      Month  Day     Price
# 0       12   31  21078000
# 1       12   30  21092000
# 2       12   29  21198000
# 3       12   28  21051000
# 4       12   27  21326000
# ..     ...  ...       ...
# 360      1    5  53788000
# 361      1    4  56030000
# 362      1    3  56626000
# 363      1    2  57496000
# 364      1    1  57989000
#
# [365 rows x 3 columns]

# %%
bithumb1 = bithumb1.pivot("Month", "Day", "Price")

# %%
bithumb1
# Out:
# Day            1           2           3           4           5           6   \
# Month
# 1      57989000.0  57496000.0  56626000.0  56030000.0  53788000.0  53245000.0
# 2      47762000.0  45437000.0  45754000.0  50604000.0  50734000.0  51745000.0
# 3      53798000.0  53398000.0  51780000.0  48411000.0  48620000.0  47777000.0
# 4      56502000.0  56051000.0  56651000.0  57026000.0  56149000.0  53020000.0
# 5      49343000.0  49453000.0  48677000.0  50595000.0  47575000.0  46982000.0
# 6      37843000.0  38344000.0  37856000.0  37906000.0  38005000.0  39589000.0
# 7      25539000.0  25432000.0  25432000.0  26424000.0  26534000.0  26947000.0
# 8      30862000.0  30772000.0  30689000.0  30310000.0  30774000.0  30490000.0
# 9      27592000.0  27560000.0  27410000.0  27525000.0  27297000.0  26353000.0
# 10     27890000.0  27687000.0  28293000.0  28982000.0  28715000.0  28421000.0
# 11     28767000.0  28670000.0  28737000.0  29401000.0  29768000.0  29455000.0
# ...

# %%
plt.figure(figsize=(16,12))
sns.heatmap(bithumb1, cmap='jet')
plt.show()

# %%
bithumb2 = bithumb[["Month", "Day", "Volume"]]

# %%
bithumb2
# Out:
#      Month  Day  Volume
# 0       12   31     580
# 1       12   30     660
# 2       12   29     700
# 3       12   28     820
# 4       12   27     660
# ..     ...  ...     ...
# 360      1    5    1220
# 361      1    4     430
# 362      1    3     410
# 363      1    2     220
# 364      1    1     510
#
# [365 rows x 3 columns]

# %%
bithumb2 = bithumb2.pivot("Month", "Day", "Volume")

# %%
plt.figure(figsize=(16,12))
sns.heatmap(bithumb2, cmap='jet')
plt.show()
